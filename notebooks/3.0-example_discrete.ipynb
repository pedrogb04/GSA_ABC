# %%
# %load_ext autoreload
# %autoreload 2

# %%
import csv
import numpy as np
import os
import time

from benchmarks import get_function_details
from src.entities import GSA


# Select optimizers
gsa = True  # Code by Himanshu Mittal

# Select benchmark function
F1 = True

algorithm = [gsa]
objective_function = [F1]

# Select number of repetitions for each experiment. 
# To obtain meaningful statistical results, usually 30 independent runs 
# are executed for each algorithm.
runs = 3

# Select chaotic constant
chaotic_constant = True

# Select general parameters for all optimizers (population size, number of iterations)
population_size = 30
iterations = 100

# Export results ?
export = False

# ExportToFile="YourResultsAreHere.csv"
# Automaticly generated name by date and time

save_path = "data/output/"
if not os.path.exists(save_path):
    os.makedirs(save_path)

ExportToFile = save_path + "experiment" + time.strftime("%Y-%m-%d-%H-%M-%S_") + str(chaotic_constant) + ".csv"

# Check if it works at least once
atLeastOneIteration = False

# CSV Header for the convergence
CnvgHeader = []
# SolHeader=[]

for l in range(iterations):
    CnvgHeader.append("Iter" + str(l + 1))
    # SolHeader.append("Sol_Iter"+str(l+1))

for j in range(len(objective_function)):
    if objective_function[j]:  # start experiment if an Algorithm and an objective function is selected
        for k in range(0, runs):
            function_details = get_function_details(j)
            real_boundaries = [(function_details['lower_bound'], function_details['upper_bound']) for _ in range(function_details['dim'])]
            function_details = get_function_details(j)
            gsa_algo = GSA(objective_function = function_details['function'],
                           r_dim=function_details['dim'],
                           d_dim=0,
                           boundaries={'real': real_boundaries, 'discrete': []})
            
            gsa_algo.optimize(population_size=population_size,
                              iters=iterations,
                              chaotic_constant=True)

            if export:
                with open(ExportToFile, 'a') as out:
                    writer = csv.writer(out, delimiter=',')
                    if not atLeastOneIteration:  # just one time to write the header of the CSV file
                        header = np.concatenate(
                            [["Optimizer", "objfname", "startTime", "EndTime", "ExecutionTime"], CnvgHeader])
                        print(header)
                        writer.writerow(header)
                    a = np.concatenate(
                        [[gsa_algo.objective_function_name,
                          gsa_algo.start_time,
                          gsa_algo.end_time,
                          gsa_algo.execution_time],
                          gsa_algo.convergence])
                    writer.writerow(a)
                out.close()
            atLeastOneIteration = True  # at least one experiment

if not atLeastOneIteration:  # Faild to run at least one experiment
    print("No Optimizer or Cost function is selected. Check lists of available optimizers and cost functions")
# Out:
# GSA is optimizing  "F1"
# ['At iteration 1 the best fitness is 12919.901471174448']
# ['At iteration 2 the best fitness is 7162.131267040563']
# ['At iteration 3 the best fitness is 2436.07871100454']
# ['At iteration 4 the best fitness is 737.771010308063']
# ['At iteration 5 the best fitness is 737.771010308063']
# ['At iteration 6 the best fitness is 583.7696882572276']
# ['At iteration 7 the best fitness is 536.6482199661037']
# ['At iteration 8 the best fitness is 509.93073538215594']
# ['At iteration 9 the best fitness is 355.21069099989853']
# ['At iteration 10 the best fitness is 355.21069099989853']
# ['At iteration 11 the best fitness is 314.9791266066674']
# ['At iteration 12 the best fitness is 295.346832744305']
# ['At iteration 13 the best fitness is 236.3326667128362']
# ['At iteration 70 the best fitness is 0.04063649676399534']
# ['At iteration 71 the best fitness is 0.04063649676399534']
# ['At iteration 72 the best fitness is 0.04063649676399534']
# ['At iteration 73 the best fitness is 0.04063649676399534']
# ['At iteration 74 the best fitness is 0.04063649676399534']
# ['At iteration 75 the best fitness is 0.04063649676399534']
# ['At iteration 76 the best fitness is 0.04063649676399534']
# ['At iteration 77 the best fitness is 0.03466480823906848']
# ['At iteration 78 the best fitness is 0.019055368614509877']
# ['At iteration 79 the best fitness is 0.017364464950267618']
# ['At iteration 80 the best fitness is 0.017364464950267618']
# ['At iteration 81 the best fitness is 0.017364464950267618']
# ['At iteration 82 the best fitness is 0.007278679261195952']
# ['At iteration 83 the best fitness is 0.007278679261195952']
# ['At iteration 84 the best fitness is 0.005155974416765149']
# ['At iteration 85 the best fitness is 0.005155974416765149']
# ['At iteration 86 the best fitness is 0.0032241390042297476']
# ['At iteration 87 the best fitness is 0.0032241390042297476']
# ['At iteration 88 the best fitness is 0.0032237855794170493']
# ['At iteration 89 the best fitness is 0.0032237855794170493']
# ['At iteration 90 the best fitness is 0.0032237855794170493']
# ['At iteration 91 the best fitness is 0.0022288322064790683']
# ['At iteration 92 the best fitness is 0.0015551959827356668']
# ['At iteration 93 the best fitness is 0.0015551959827356668']
# ['At iteration 94 the best fitness is 0.001136046945392606']
# ['At iteration 95 the best fitness is 0.0007306911719276107']
# ['At iteration 96 the best fitness is 0.0007306911719276107']
# ['At iteration 97 the best fitness is 0.00035455155052155736']
# ['At iteration 98 the best fitness is 0.00019303846748417618']
# ['At iteration 99 the best fitness is 0.00010465831430210082']
# ['At iteration 100 the best fitness is 0.00010465831430210082']
# ['Optimizer' 'objfname' 'startTime' 'EndTime' 'ExecutionTime' 'Iter1'
#  'Iter2' 'Iter3' 'Iter4' 'Iter5' 'Iter6' 'Iter7' 'Iter8' 'Iter9' 'Iter10'
#  'Iter11' 'Iter12' 'Iter13' 'Iter14' 'Iter15' 'Iter16' 'Iter17' 'Iter18'
#  'Iter19' 'Iter20' 'Iter21' 'Iter22' 'Iter23' 'Iter24' 'Iter25' 'Iter26'
#  'Iter27' 'Iter28' 'Iter29' 'Iter30' 'Iter31' 'Iter32' 'Iter33' 'Iter34'
#  'Iter35' 'Iter36' 'Iter37' 'Iter38' 'Iter39' 'Iter40' 'Iter41' 'Iter42'
#  'Iter43' 'Iter44' 'Iter45' 'Iter46' 'Iter47' 'Iter48' 'Iter49' 'Iter50'
#  'Iter51' 'Iter52' 'Iter53' 'Iter54' 'Iter55' 'Iter56' 'Iter57' 'Iter58'
#  'Iter59' 'Iter60' 'Iter61' 'Iter62' 'Iter63' 'Iter64' 'Iter65' 'Iter66'
#  'Iter67' 'Iter68' 'Iter69' 'Iter70' 'Iter71' 'Iter72' 'Iter73' 'Iter74'
#  'Iter75' 'Iter76' 'Iter77' 'Iter78' 'Iter79' 'Iter80' 'Iter81' 'Iter82'
# ['At iteration 60 the best fitness is 0.14399881386515762']
# ['At iteration 61 the best fitness is 0.13921390098006978']
# ['At iteration 62 the best fitness is 0.05938120999955395']
# ['At iteration 63 the best fitness is 0.05938120999955395']
# ['At iteration 64 the best fitness is 0.05938120999955395']
# ['At iteration 65 the best fitness is 0.05938120999955395']
# ['At iteration 66 the best fitness is 0.05938120999955395']
# ['At iteration 67 the best fitness is 0.05938120999955395']
# ['At iteration 68 the best fitness is 0.05938120999955395']
# ['At iteration 69 the best fitness is 0.05520683043922105']
# ['At iteration 70 the best fitness is 0.041536197755474714']
# ['At iteration 71 the best fitness is 0.04013670908629916']
# ['At iteration 72 the best fitness is 0.04013670908629916']
# ['At iteration 73 the best fitness is 0.03730989663469379']
# ['At iteration 74 the best fitness is 0.03730989663469379']
# ['At iteration 75 the best fitness is 0.021837418076403613']
# ['At iteration 76 the best fitness is 0.021837418076403613']
# ['At iteration 77 the best fitness is 0.021837418076403613']
# ['At iteration 78 the best fitness is 0.021837418076403613']
# ['At iteration 79 the best fitness is 0.021837418076403613']
# ['At iteration 80 the best fitness is 0.021837418076403613']
# ['At iteration 81 the best fitness is 0.021837418076403613']
# ['At iteration 82 the best fitness is 0.018771775398961736']
# ['At iteration 83 the best fitness is 0.012707648422761942']
# ['At iteration 84 the best fitness is 0.007655443850834796']
# ['At iteration 85 the best fitness is 0.007655443850834796']
# ['At iteration 86 the best fitness is 0.004119481615269613']
# ['At iteration 87 the best fitness is 0.0032875083490765387']
# ['At iteration 88 the best fitness is 0.0032875083490765387']
# ['At iteration 89 the best fitness is 0.0032875083490765387']
# ['At iteration 90 the best fitness is 0.0032875083490765387']
# ['At iteration 91 the best fitness is 0.0032875083490765387']
# ['At iteration 92 the best fitness is 0.0023790665787660264']
# ['At iteration 93 the best fitness is 0.0006046337728976276']
# ['At iteration 94 the best fitness is 0.00044696178107732267']
# ['At iteration 95 the best fitness is 0.00044696178107732267']
# ['At iteration 96 the best fitness is 0.00044696178107732267']
# ['At iteration 97 the best fitness is 0.0003135198964700897']
# ['At iteration 98 the best fitness is 0.00029520022017637466']
# ['At iteration 99 the best fitness is 0.00029520022017637466']
# ['At iteration 100 the best fitness is 0.0002945102136298846']

# %%
import pandas as pd

# %%
output_file = "../data/output/experiment2024-02-06-11-24-28.csv"

data = pd.read_csv(output_file)

# %%
data
# Out:
#   Optimizer objfname            startTime              EndTime  ExecutionTime  \
# 0       GSA       F1  2024-02-06-11-24-28  2024-02-06-11-24-29        0.54548
#
#          Iter1         Iter2        Iter3        Iter4       Iter5  ...  \
# 0  21634.17186  13724.250576  5564.349644  1210.276746  439.623279  ...
#
#        Iter91      Iter92      Iter93      Iter94      Iter95      Iter96  \
# 0  317.524882  317.524882  317.524882  317.524882  317.524882  317.524882
#
#        Iter97      Iter98      Iter99     Iter100
# 0  317.524882  317.524882  317.524882  317.524882
#
# [1 rows x 105 columns]
